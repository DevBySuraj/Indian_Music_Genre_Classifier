# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Is built with CUDA:", tf.test.is_built_with_cuda())
# Out:
# Num GPUs Available:  1
# Is built with CUDA: True

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# these above two code confirm gpu is not being seen or used by tensorflow
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15210238410170994793
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3673161728
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15287162905784345613
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
import tensorflow as tf

# Check and initialize GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU Detected and Ready: {gpus[0]}")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
else:
    print("No GPU found. Check NVIDIA drivers (Version 525+ recommended).")
# Out:
# GPU Detected and Ready: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# in this training of the data cpu was being used which is slow and takes approx 1s for each step out of 255 for 1 epoch

# gpu is not used by tensorflow
# print(tf.config.list_physical_devices('GPU'))

# says: below r

# it is saying  
# Num GPUs Available:  0
# Is built with CUDA: False


# If you want to unlock that 3050 speed, you usually need these three things installed on your Windows laptop:

# NVIDIA Studio/Game Ready Driver: (You likely already have this).

# CUDA Toolkit: The "math engine" for NVIDIA cards.

# cuDNN: The library specifically for Deep Neural Networks.
    

# The main issue was of Cuda and cuDNN libraries they were not installed in this env
# in the tf_env(yt project) everything was installed by me as i followed the video


# on the tensorflow website it was all available 

#the current tensorflow version is 2.10.0 gpu supported by tf ,above not supported (requires special setup windows subsystem or etc.)


#installed tf 2.9 for spleeter support also

# %%
python -c "import tensorflow as tf; print(tf.reduce_sum(tf.random.normal([1000, 1000])))"

can run python command in shell by - python -c then "code"
# Out:
#   Cell In[5], line 1
#     python -c "import tensorflow as tf; print(tf.reduce_sum(tf.random.normal([1000, 1000])))"
#               ^
# SyntaxError: invalid syntax

# %%
import tensorflow as tf
from spleeter.separator import Separator

# Check 1: Is the 3050 awake?
gpus = tf.config.list_physical_devices('GPU')
print(f"GPU Detected: {'YES' if gpus else 'NO'}")

# Check 2: Can Spleeter initialize?
try:
    separator = Separator('spleeter:2stems')
    print("Spleeter initialized successfully!")
except Exception as e:
    print(f"Spleeter Error: {e}")
# Out:
# GPU Detected: YES
# Spleeter initialized successfully!

# %%
# both the tf (gpu support) and spleeter are now working
# Out:
#   Cell In[7], line 1
#     both the tf (gpu support) and spleeter are now working
#          ^
# SyntaxError: invalid syntax
